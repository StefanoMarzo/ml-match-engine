# %% [markdown]
# ### Imports

# %%
# libraries
import pandas as pd
import unicodedata
import re
from rank_bm25 import BM25L

# Pandas config
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ### Load data

# %%
title_not_matched = pd.read_parquet('data/title_not_matched.parquet')
color_not_matched = pd.read_parquet('data/color_not_matched.parquet')

offers_training_df = pd.read_parquet('../data/offers_training.parquet')
offers_test_df = pd.read_parquet('../data/offers_test.parquet')
matches_training_df = pd.read_parquet('../data/matches_training.parquet')

# %% [markdown]
# ### Process text for data cleaning

# %%
stop_word_list = []
with open('./text_processing/german_stopwords.txt', "r") as f:
    stop_word_list = f.read().split()
class TextTransformer:
    def processed_text(self, text):
        if text is None:
            return ''
        #lower
        processed = text.lower()
        #remove accents
        processed = self.simplify(processed)
        #remove special characters
        processed = ''.join(c if c.isalnum() or c == ' ' else ' ' for c in processed)
        #remove unnecessary double spaces
        processed = re.sub(' +', ' ', processed)
        #strip
        processed = processed.strip()
        #remove stopwords
        processed_list = [word for word in processed.split() if word not in stop_word_list]
        return ' '.join(processed_list)
    
    def simplify(self, text):
        try:
            text = unicode(text, 'utf-8')
        except NameError:
            pass
        text = unicodedata.normalize('NFD', text).encode('ascii', 'ignore').decode("utf-8")
        return str(text)
with open('color_processing/kfix_de.txt') as f:
    color_kfix_list = f.read().splitlines() 

with open('color_processing/primary_colors_de.txt') as f:
    primary_colors = f.read().splitlines() 
color_matches = {}
with open('color_processing/color_matches_de.txt') as f:
    for line in f:
        (key, val) = line.split(':')
        val = val.strip()
        color_matches[key] = val
with open('title_processing/kfix_de.txt') as f:
    clothes_kfix_list = f.read().splitlines() 

with open('title_processing/primary_clothes_de.txt') as f:
    primary_clothes = f.read().splitlines() 
clothes_matches = {}
with open('title_processing/clothes_matches_de.txt') as f:
    for line in f:
        (key, val) = line.split(':')
        val = val.strip()
        clothes_matches[key] = val
class SpecificTrasformer(TextTransformer):
    def __init__(self,
                 kfix_list, 
                 matches, 
                 primary):
        self.kfix_list = kfix_list
        self.matches = matches
        self.primary = primary
    def separe_word(self, text, word):
        i = text.find(word)
        text = text[:i] + ' ' + text[i:] if i != -1 else text
        return text[:i+len(word)+1] + ' ' + text[i+len(word)+1:] if i != -1 else text
    def separe_words(self, text):
        for color in self.primary:
            text = self.separe_word(text, color)
        return text
    def replace_words(self, text):
        for k, v in self.matches.items():
            text = text.replace(k, v)
        return text
    def remove_kfix(self, text):
        for suffix in self.kfix_list:
            text = text.replace(suffix, '')
        return text
    
    def processed_text(self, text):
        splitted = super().processed_text(text).split()
        #1 transform matches
        splitted = [self.replace_words(text) for text in splitted]
        #2 suffix removal
        splitted = [self.remove_kfix(text) for text in splitted]
        #separate primary colors
        splitted = [self.separe_words(term) for term in splitted]
        return re.sub(' +', ' ', ' '.join(splitted).strip())

# %% [markdown]
# ### Instance of text transformers

# %%
tt = TextTransformer()
ct = SpecificTrasformer(color_kfix_list, color_matches, primary_colors)
titlet = SpecificTrasformer(clothes_kfix_list, clothes_matches, primary_clothes)

# %% [markdown]
# ### Clean DFs

# %%
zalando_prod_training = offers_training_df.loc[offers_training_df['shop'] == 'zalando']
zalando_prod_training = zalando_prod_training\
                    .loc[zalando_prod_training['offer_id'].isin(matches_training_df['zalando'])]
zalando_prod_training['brand'] = zalando_prod_training['brand']\
                    .apply(lambda x: tt.processed_text(x))
zalando_prod_training['title'] = zalando_prod_training['title']\
                    .apply(lambda x: titlet.processed_text(x))
zalando_prod_training['color'] = zalando_prod_training['color']\
                    .apply(lambda x: ct.processed_text(x))

aboutyou_prod_training = offers_training_df.loc[offers_training_df['shop'] == 'aboutyou']
aboutyou_prod_training['brand'] = aboutyou_prod_training['brand']\
                    .apply(lambda x: tt.processed_text(x))
aboutyou_prod_training['title'] = aboutyou_prod_training['title']\
                    .apply(lambda x: titlet.processed_text(x))
aboutyou_prod_training['color'] = aboutyou_prod_training['color']\
                    .apply(lambda x: ct.processed_text(x))

# %% [markdown]
# ### BM25 setup

# %%
class TextRelevance:
    def __init__(self, text, relevance):
        self.text = text
        self.relevance = relevance
    def __repr__(self):
        return self.text + ' ' + str(self.relevance)
    def __eq__(self, other):
        return self.text == other.text
    def __hash__(self):
        return hash(self.text)

# %%
class BM25Z(BM25L):
    def __init__(self, corpus):
        super().__init__(self.process_list(corpus))
        self.corpus = self.process_list(corpus)
    def process_list(self, titles_list):
        return [text.split() for text in titles_list if text is not None]
    def processed_text(self, text):
        return tt.processed_text(text)
    def get_corpus_str(self):
        return [' '.join(el) for el in self.corpus]
    def get_corpus_scores(self, query):
        query = self.processed_text(query).split()
        return [TextRelevance(x,y) for x, y in zip(self.get_corpus_str(), self.get_scores(query))]
    def get_relevant_results(self, query, threshold=0):
        res = [el for el in self.get_corpus_scores(query) if el.relevance > threshold]
        res = sorted(res, key=lambda x: x.relevance, reverse=True)
        return res

# %% [markdown]
# ### Getting all non matching titles

# %%
title_not_matching_offers = aboutyou_prod_training.loc[
    aboutyou_prod_training['offer_id'].isin(title_not_matched['aboutyou'])
]
bm25matcher_title = BM25Z(list(title_not_matching_offers['title']))

# %% [markdown]
# ### Getting all non matching colors

# %%
color_not_matching_offers = aboutyou_prod_training.loc[
    aboutyou_prod_training['offer_id'].isin(color_not_matched['aboutyou'])
]
bm25matcher_color = BM25Z(list(color_not_matching_offers['color']))

# %% [markdown]
# ### Identify common substrings

# %%
def longest_substring(str_1, str_2):
    to_split = str_1 if len(str_1) < len(str_2) else str_2
    to_comp = str_1 if len(str_1) > len(str_2) else str_2
    if len(to_split) < 3 or len(to_comp) < 3:
        return None
    sub = all_substr(to_split)
    for el in sub:
        if el in to_comp:
            return el
    return None
        
def next_sub_substr(to_split):
    l = len(to_split)
    return to_split[:l-1] 

def next_sum_substr(to_split):
    l = len(to_split)
    return to_split[1:] 

def all_sub_substr(to_split):
    l = [to_split]
    for i in range(len(to_split) - 3):
        to_split = next_sub_substr(to_split)
        l += [to_split]
    return l

def all_substr(to_split):
    l = all_sub_substr(to_split)
    size = len(to_split) - 3
    for i in range(size):
        to_split = next_sum_substr(to_split)
        l += all_sub_substr(to_split)
    return sorted(l, key=len, reverse=True)

# %% [markdown]
# ### Mine common substrings
# e.g. Canvasgürtel, Ledergürtel -> gürtel

# %%
def mine_common_terms(not_match_df, matcher, attribute):
    common_terms = []
    for i in range(len(not_match_df)):
        z_id = not_match_df.loc[i]['zalando']
        a_id = not_match_df.loc[i]['aboutyou']
        z_ti = zalando_prod_training.loc[zalando_prod_training['offer_id'] == z_id][attribute].values[0]
        a_ti = aboutyou_prod_training.loc[aboutyou_prod_training['offer_id'] == a_id][attribute].values[0]
        rel_titles = [el.text for el in matcher.get_relevant_results(z_ti)]
        if a_ti not in rel_titles:
            com = longest_substring(z_ti, a_ti)
            common_terms += [com] if com is not None else []
    common_terms = [el for el in common_terms if ' ' not in el]
    filter_common_terms = []
    for el in common_terms:
        for term in common_terms:
            if el in term and len(el) < len(term):
                filter_common_terms += [el]
    to_rem = set(filter_common_terms)
    common_terms = [el for el in common_terms if el not in to_rem]
    return set(common_terms)

# %%
title_common_updated = mine_common_terms(title_not_matched, bm25matcher_title, 'title')
color_common_updated = mine_common_terms(color_not_matched, bm25matcher_color, 'color')

# %% [markdown]
# ### These terms will be added to a list to read from
# primary_clothes_de.txt

# %%
for term in title_common_updated:
    print(term)
# Out:
# ack
# ron
# nte
# rist
# lad
# tanga
# lei
# analoguhr
# and
# rte
# ony
# aurora
# anzug
# sch

# %% [markdown]
# ### These terms will be added to a list to read from
# primary_colors_de.txt

# %%
for term in color_common_updated:
    print(term)
# Out:
# ros
# ran
# aubergine
# rau
# sch

# %%
def print_attributes_values(z_id, a_id, attribute):
    z_a = zalando_prod_training\
                        .loc[zalando_prod_training['offer_id'] == z_id][attribute].values[0]
    a_a = aboutyou_prod_training\
                        .loc[aboutyou_prod_training['offer_id'] == a_id][attribute].values[0]
    print(z_a, '-', a_a)

# %%
for i in color_not_matched.index:
    z_id = color_not_matched.loc[i]['zalando']
    a_id = color_not_matched.loc[i]['aboutyou']
    print_attributes_values(z_id, a_id, 'color')
#matches_training_df.loc[0]['zalando']
# Out:
# grun - braun braun
# braun - gelb gelb
# grun - senf gelb
# schwarz - dunkel grun grun
# braun - wei wei
# dunkel blau - schwarz schwarz
# braun - wei wei
# grau meliert - braun wei
# dunkel blau - wei schwarz schwarz
# schwarz - dunkel grun grun
# braun - wei wei
# grun - braun schwarz braun
# schwarz - braun gold braun
# rot - schwarz schwarz
# gold - creme braun
# dunkel grau - grun grun
# braun - hell grau grau
# schwarz - grau grau
# wei - creme braun hell braun schwarz braun
# grun - brokat braun
# braun - hell grau grau
# grau - schwarz schwarz
# grun - aqua blau
# schwarz blau - dunkel grau grau
# braun - rosa rosa
# definiert - alt rosa rosa
# blau - misch misch
# orange - rost braun braun
# misch - blau blau cranberry blau
# braun - schwarz wei schwarz wei
# wei - braun braun
# dunkel blau - misch misch
# hell braun - taupe grau
# orange - schwarz braun rot gelb braun
# dunkel blau - schwarz schwarz
# grun - braun braun
# wei - transparent gold gold
# grun - dunkel grau grau
# rot - orange orange
# definiert - wei
# orange - rost braun braun
# schwarz - misch braun
# braun - gelb gelb
# braun - wei aqua wei
# wei - braun braun
# misch - jade wei hell grau schwarz grun
# braun - grau orange orange
# taupe - hell braun braun braun
# grun - grau misch grau
# definiert - braun
# rosa - melone wei schwarz rot
# wei - braun rost braun schwarz braun braun
# rosa - cappuccino braun
# misch - wei braun wei
# braun - rosa rosa
# wei - misch creme braun misch
# gunmetal - schwarz gold schwarz
# misch - wei gold rosa wei
# misch - rosa alt rosa tauben blau braun blau
# grun - mokka braun
# braun - grau rosa grun rosa grau
# braun - jade grun
# schwarz - grau dunkel grau grau
# dunkel braun - schwarz schwarz
# schwarz - misch dunkel grau grau
# grun - braun blau orange misch
# schwarz - grun grun
# rosa - blau misch blau
# wei - ecru braun
# silber - grau grau
# rosa - braun gold gelb wei
# wei - silber silber
# grau - schwarz gold schwarz
# rot - wei orange orange
# dunkel grun - schwarz grau
# misch - blau gelb wei rot schwarz blau schwarz
# grun - dunkel braun braun
# braun - wei schwarz wei
# rot - rosa rosa
# braun - wei schwarz wei
# grun - kitt braun
# schwarz - grau wei grau
# wei - dunkel braun braun
# braun - wei schwarz wei
# grun - taupe grau
# braun - schwarz wei creme schwarz
# dunkel grun - braun hell braun schwarz braun
# schwarz - misch misch
# grau - blau wei blau wei
# grun - grau grau
# rosa - braun meliert braun
# grun - misch misch
# misch - blau gelb wei schwarz gelb blau
# rosa - brokat braun
# rosa - grau rot grau rot
# schwarz - grau rosa grau
# braun - wei wei
# schwarz - braun braun braun
# misch - orange schwarz wei feuer rot grun orange
# blau - misch rosa
# braun - wei taupe wei
# grun - hell braun braun
# braun - wei wei
# braun - creme wei
# blau grau - grun wei grun
# wei - hell braun braun
# dunkel grau - schwarz schwarz
# schwarz meliert - dunkel grau grau
# grun - hell grau grau
# rosa - hell gelb dunkel blau gelb blau
# braun - wei wei
# stein - taupe braun grau
# schwarz - misch misch
# rosa - braun braun
# braun - wei wei
# wei - schwarz schwarz
# misch - grau cyclam alt rosa wei rosa
# gelb - mauve grau rosa grau orange orange
# grun - dunkel braun braun
# rot - misch misch
# hell braun - gelb meliert gelb
# silber - grau meliert grau
# blau - misch misch
# schwarz - schlamm grun grun
# rosa - braun braun
# schwarz - dunkel grun grun
# senf - gold gelb gelb
# braun - grau grau
# misch - nacht blau wei grau rosa grun blau
# orange - schwarz braun rot gelb misch
# dunkel grun - braun braun
# grun - safran orange
# braun - schwarz blau schwarz
# dunkel blau - misch misch
# braun - wei wei
# braun - ecru wei
# schwarz - braun nacht blau blau
# hell braun - rost rot rot
# braun - grau rosa rosa grun grau
# rot - purpur rosa
# royal - dunkel blau blau
# braun - taupe grau
# rot - misch wei wei
# definiert - wei
# schwarz - blau misch
# hell braun - grau meliert grau
# braun - grun grun
# hell rot - alt rosa rosa
# braun - rosa rosa
# braun - misch misch
# hell grau - woll wei wei
# braun - grun grun
# orange - dunkel gelb wei gelb
# taupe - schlamm braun
# dunkel blau - schwarz schwarz
# grau - dunkel grun grun grun grun
# braun - wei dunkel grun wei
# apricot - braun braun
# wei - schwarz schwarz
# blau - dunkel grun grun
# blau - graphit wei rauch grau grau
# stein - wei schwarz tauben blau blau schwarz
# schwarz - grau creme grun braun
# schwarz - braun misch braun
# rot - alt rosa rosa
# braun - grun grun
# rot metallic - braun braun
# hell braun - gold gelb gelb
# wei - misch misch
# grun - schwarz wei schwarz
# grun - braun braun
# braun - blau blau
# grau - schwarz neon grun schwarz schwarz
# definiert - aubergine
# misch - braun schwarz creme braun
# braun - wei wei
# grau - braun braun
# braun - wei wei
# taupe - braun braun
# taupe - braun braun
# silber - rosa gold gold
# orange - braun braun
# misch - hell rosa schwarz blau wei kiwi rosa
# braun - grun grun
# rosa - kiwi grau orange dunkel orange mauve misch
# schwarz - braun dunkel blau braun blau
# braun - wei wei
# definiert - gold
# schwarz - blau blau
# silber - hell grau schwarz grau
# braun - hell grau grau
# rot - braun misch braun
# braun - wei wei
# silber - rosa gold transparent gold
# braun - grun grun
# dunkel grun meliert - grau grau
# rot - pflaume rosa
# braun - wei schwarz schwarz
# wei - misch puder rosa
# definiert - wei
# schwarz - grau grau
# wei - braun braun
# taupe - braun braun braun
# braun - wei blau wei
# braun - hell rosa rosa
# braun - schwarz hell grau grau
# rosa - blau wei blau
# wei - silber transparent silber
# rot metallic - braun wei braun
# grun - grau grau
# definiert - transparent
# braun - orange wei rost rot orange
# royal - blau blau
# taupe - braun braun
# braun - schwarz gelb grun gelb
# dunkel grau - braun schwarz braun
# wei - hell grau hell braun rost braun rosa hell rosa grau braun
# schwarz - dunkel blau blau
# ocker - rosa rosa
# braun - schwarz orange wei grun orange
# hell grun - grau blau blau
# grau - braun wei
# schwarz - braun braun
# gelb - apricot wei orange
# schwarz - grau grau
# braun - hell grau grau
# ocker - hell braun wei rosa dunkel rot grun braun
# misch - silber dunkel rosa silber
# rot metallic - misch misch
# hell blau - grau grau
# schwarz - braun braun
# blau - grau braun grun
# wei - gold gold
# apricot - rot wei orange
# senf - gelb hell gelb gelb
# wei - silber silber
# misch - schwarz dunkel rosa braun schwarz
# gold - gelb gelb
# dunkel braun - purpur rosa
# blau - grau rosa grun
# misch - honig wei gelb
# grau - schwarz wei wei
# blau - graphit misch grau
# gunmetal - schwarz schwarz
# braun - ecru wei
# wei - braun creme braun
# grun - wei dunkel braun braun
# grau - gelb wei schwarz gelb
# rosa - dunkel grau misch grau
# rosa - rot rot
# dunkel blau - rosa gelb wei rosa
# silber - schwarz grau
# rot - rosa wei rosa
# braun - woll wei wei
# rot - rosa rosa
# silber - schwarz wei schwarz
# braun - alt rosa orange rosa rosa
# braun - grau grau
# misch - jade rosa grun
# schwarz - schoko grun wei braun
# braun - wei schwarz wei
# braun - wei wei
# dunkel blau - misch misch
# stein - silber grau grau
# mauve - alt rosa gelb melone creme rosa braun
# rot - schwarz schwarz
# rosa - braun braun
# dunkel blau - schwarz schwarz
# wei - braun schwarz braun schwarz
# blau - basalt grau grau
# rot - rost braun misch braun
# grau - tauben blau blau
# braun - wei schwarz wei
# dunkel rot - braun braun
# royal - blau dunkel blau blau
# wei - schwarz schwarz
# transparent - silber silber
# grau - grun grun
# silber - wei rosa wei rosa
# wei - gold transparent gold
# misch - wei schwarz hell blau wei
# braun - hell grun grun
# braun - wei wei
# silber - rosa gold transparent gold
# misch - schwarz gelb schwarz gelb
# dunkel grun - schlamm grau
# grun - grau grau
# rosa - grau rot rot
# grun - umbra braun
# braun - hell gelb gelb
# rosa - hell blau blau
# braun - woll wei wei
# braun - woll wei schwarz gold rot wei
# senf - braun braun
# misch - schwarz rot wei grun schwarz rot
# dunkel blau - grun orange schwarz schwarz orange
# braun - woll wei wei
# braun - schwarz honig gold schwarz
# grun - misch misch
# rot - aubergine rosa
# schwarz meliert - dunkel grau grau
# braun - woll wei wei
# braun - wei taupe grau
# dunkel blau - misch misch
# grun - rot orange
# rot - rosa rosa
# misch - hell blau dunkel blau rosa blau rosa
# braun - wei wei
# rosa - misch misch
# grun meliert - senf gelb
# rot - orange orange
# braun - rosa rosa
# grau - misch schwarz schwarz
# braun - woll wei wei
# misch - schwarz wei schwarz
# misch - wei rosa alt rosa braun blau rosa
# dunkel grun - schwarz grau
# misch - rosa rosa aqua grun rosa
# braun - hell grau grau
# rosa - rot orange
# grun - braun braun
# braun - creme wei
# definiert - wei
# braun - grun grun
# rot metallic - braun ecru braun braun
# braun - wei nacht blau wei
# braun - melone rot
# schwarz - basalt grau grau
# misch - rosa wei hell blau blau wei rosa
# misch - grau meliert dunkel grau jade hell blau grau
# grun - greige grau
# rosa - braun braun
# wei - silber silber
# braun - wei wei
# braun - rosa rosa
# rosa - kirsch rot rot
# grun meliert - schwarz braun braun
# wei - silber transparent silber
# dunkel gelb - orange orange
# grun - wei schwarz wei
# braun - silber silber
# braun - wei wei
# wei - silber silber
# rot - aubergine rosa
# taupe - braun braun
# rosa - hummer orange
# braun - creme wei
# senf - honig gelb
# hell braun - silber grau schwarz grau
# grun - aqua blau
# misch - silber grun blau silber
# grun - braun braun
# braun - wei wei
# rosa - braun braun
# misch - creme rot grau grun wei
# braun - rosa
# senf - braun braun
# misch - schwarz grau schwarz grau
# braun - wei wei
# braun - schwarz rosa grun misch
# dunkel blau - grau grau
# braun - wei wei
# grun - braun braun
# schwarz - grau meliert grau
# braun ne - blau grun
# definiert - transparent
# braun - grun grun
# braun - wei schwarz kitt wei
# rot - misch misch
# rot - kas braun ienbraun braun
# misch - schwarz schwarz
# braun - schwarz wei schwarz wei
# rosa - marine rauch blau blau
# rosa - hell braun hell gelb grun braun
# grau - schwarz schwarz
# schwarz - hell grau grau
# braun - rosa hell rosa hell orange rosa
# braun - wei wei
# definiert - creme wei schwarz
# misch - schwarz rot kitt dunkel braun braun
# rosa - sepia braun
# braun - hell grau grau
# grun - wei meliert senf gelb
# wei - creme braun
# dunkel blau - schwarz schwarz
# braun - wei misch wei
# schwarz - dunkel grau grau
# rot - rost braun braun
# braun - wei wei
# gelb - himmel blau gold blau
# braun - wei wei
# rosa - hell braun braun
# grau - braun schwarz braun
# braun - greige grau
# gold - hell braun chamois braun
# misch - braun grau gelb hell blau grau rosa grau orange wei
# blau - lavendel rosa
# schwarz - misch misch
# grun - braun
# braun - grau grau
# orange - gold gelb gelb
# rot metallic - rosa rosa
# grun - blau wei wei
# taupe - hell braun wei braun
# wei - schwarz grau
# hell braun - rosa rosa
# hell blau - grun grun
# blau - rauch grau grau
# braun - wei wei
# braun - eosin rosa
# braun - misch misch
# schwarz - dunkel grau grau grau
# rosa - grun grun
# grun - taupe grau
# dunkel blau - misch misch
# rosa - schwarz wei rost rot senf misch
# grau - schwarz schwarz
# braun - grun grun
# braun - rosa
# schwarz - dunkel grun grun
# royal - blau blau
# misch - braun schwarz rot braun
# grau - braun wei cappuccino braun wei
# schwarz - graphit grau
# schwarz - grau grau
# wei - schwarz creme braun
# grun - stone grau
# dunkel blau - schwarz wei schwarz wei
# wei - schwarz schwarz
# blau - grau grau
# rosa - rauch blau blau
# grun - braun braun
# schwarz - misch misch
# braun - woll wei wei
# dunkel blau - schwarz wei schwarz
# schwarz - braun misch braun
# rosa - apricot blau braun
# orange - rot
# schwarz - misch misch
# rot - hummer orange
# wei - creme braun
# braun - grau wei grau wei
# dunkel rot - curry braun
# braun - greige wei schwarz grau
# blau - jade marine braun misch grun
# schwarz - grau dunkel grau grau
# blau - grun grun
# taupe - braun meliert braun
# braun - greige grau
# braun - wei wei
# rot - rosa
# braun - wei wei
# braun - rosa
# definiert - transparent
# wei - gelb blau creme braun
# dunkel blau - rot orange
# braun - hell grau grau
# ocker - braun braun
# braun - woll wei wei
# braun - dunkel grun grun
# schwarz - grau wei grau wei
# dunkel rot - wei rost braun braun
# grun - schwarz schwarz
# braun - orange gras grun hell gelb gelb
# grun - blau blau
# definiert - wei
# braun - wei wei
# grun - dunkel braun braun
# braun - wei wei
# braun - wei wei
# wei - silber silber
# braun - wei wei
# grun - braun braun
# rot - braun wei grun braun
# dunkel rot - rosa rosa
# braun - dunkel blau grau woll wei wei
# braun - greige grau
# braun - puder rosa
# misch - grau grun rot wei grun grau
# braun - grau grau
# rot - braun misch braun misch
# blau - wei gelb dunkel rosa jade grun
# blau - rosa rosa
# dunkel blau - hell grau grau
# dunkel blau - misch misch
# schwarz - grau grau
# taupe - creme braun
# gelb - braun wei pitaya wei
# schwarz - misch misch
# braun - grau grun grun
# misch - schwarz wei feuer rot schwarz
# schwarz - hell blau blau
# orange - gold gelb gelb
# braun - woll wei wei
# grun - hell braun braun
# grau - gold braun braun gold
# hell blau - rosa rosa
# dunkel blau - schwarz wei schwarz
# blau - grau grau
# wei - creme braun
# misch - wei himmel blau blau
# wei - silber silber
# schwarz - grau braun braun
# braun - wei wei
# braun - creme grau schwarz misch
# rot - misch misch
# misch - grau grun orange blau wei schwarz grun
# apricot - braun braun
# braun - wei misch wei
# stein - woll wei gold wei
# orange - senf gelb
# schwarz - misch misch
# braun - grun grun
# grau - taupe braun
# schwarz - dunkel grau grau
# braun - cappuccino brun
# blau - rost braun braun
# orange - braun braun
# misch - schwarz braun braun schwarz
# hell braun - curry gelb
# orange - rot rot
# schwarz - misch misch
# braun - grau gelb gelb
# misch - hell blau royal blau nacht blau rauch blau blau
# braun - grun grun
# taupe - dunkel braun braun
# hell grau - gelb braun gelb
# rot - creme braun
# braun - wei misch wei
# braun - grun wei blau rosa grun
# braun - wei rosa rosa schwarz hell blau misch
# schwarz - misch misch
# ocker - dunkel braun hell braun braun
# hell blau - grun senf gold gelb braun wei wei
# misch - hell grau schwarz orange grau schwarz
# braun - rosa rosa
# schwarz - misch rauch blau blau
# schwarz - creme dunkel braun orchidee braun
# gold - gelb gelb
# ocker - braun braun
# misch - grau grun rot wei grun grau
# definiert - transparent
# braun - misch misch
# braun - dunkel grun grun
# braun - hell rosa schwarz rosa schwarz
# taupe - braun braun
# braun - transparent rosa gold gold
# dunkel blau - schwarz gelb schwarz
# rosa - creme grau orange braun orange
# grau - dunkel blau blau
# blau - grun grun
# apricot - creme braun
# mauve - rosa braun wei rosa
# misch - wei blau kobalt blau schwarz hell grau wei
# orange - gold gelb gelb
# braun - gelb gelb
# braun - wei wei
# grun - gelb gelb
# blau - schwarz schwarz
# blau - rosa grun schwarz transparent misch
# grau - misch braun
# grun - wei hell grau grau
# dunkel grun - taupe blau
# braun - wei wei
# dunkel braun - wei n rot rot
# braun - wei wei
# braun - wei wei
# rot - pitaya rosa
# braun - wei wei
# misch - jade rosa grun
# grun - hell blau wei orange schwarz blau
# rot - burgunder braun dunkel grau schwarz misch
# blau - grun schwarz grun grun
# misch - grun wei nacht blau grun
# gelb - braun misch braun
# rot meliert - rosa rosa
# misch - schwarz rot creme rot braun schwarz
# rosa - braun meliert rost rot rot
# schwarz - grau meliert grau
# taupe - rosa rosa
# rosa - creme braun
# grun - braun braun
# rot metallic - rost braun schwarz wei hell braun braun
# dunkel blau - wei schwarz schwarz wei
# braun - wei rosa rosa
# wei - schwarz transparent silber schwarz
# grun - dunkel braun braun
# braun - greige grau
# grun - hell braun braun
# braun - misch misch
# rot - aubergine rosa
# schwarz - grun grun
# grun - dunkel braun braun
# wei - silber silber
# grun meliert - braun braun
# rosa - rot rot
# misch - braun hell braun schwarz braun schwarz
# braun - grun grun
# hell gelb - creme braun
# blau - basalt grau grau
# blau - grun grun
# ocker - braun schwarz braun
# grun - hell braun braun
# braun - misch misch
# gelb - braun orange schwarz braun
# rot - brombeer rosa
# braun - orange orange
# wei - creme apricot grun rosa orange
# definiert - gold
# schwarz - misch azur blau
# rot - himbeer rosa
# hell grau - blau braun blau
# silber - schwarz rosa gold gold
# misch - schwarz hell blau rosa wei grun schwarz
# silber - brokat braun
# bronze - gold gold
# senf - grun grun
# rot metallic - braun braun
# misch - wei grau meliert wei grau
# grun - hell braun braun
# braun - wei wei
# braun - wei rosa rosa
# braun - woll wei wei
# wei - ecru braun braun
# grun meliert - braun schwarz braun
# grun - grau grau
# braun - dunkel grau grau grau
# blau - dunkel rosa rosa
# braun - woll wei wei
# grau - wei wei
# grun - mokka braun
# gold - braun
# hell braun - taupe grau
# schwarz - grun dunkel grun wei grun
# misch - braun hell braun dunkel braun wei braun
# gelb - gold transparent gold
# grun - hell braun braun
# rosa - hell rot misch rot
# braun - wei wei
# braun - rosa rosa
# braun - schwarz schwarz
# schwarz - hell rosa orange rosa blau blau
# dunkel grau - hell braun braun
# schwarz - dunkel blau blau
# grau - schwarz schwarz meliert schwarz
# braun - dunkel grau schwarz grau
# grun - woll wei wei
# rosa - braun braun
# wei - ecru braun
# orange - dunkel gelb rosa gelb
# blau - grun grun
# silber - brokat braun
# definiert - braun schwarz wei grun
# braun - wei grau wei
# braun - gelb dunkel blau blau
# grau - schwarz safran schwarz
# braun - schwarz wei wei
# braun - dunkel orange orange
# schwarz - dunkel braun braun
# misch - blau senf wei blau schwarz blau
# senf - safran gelb
# grun - taupe grau
# wei - creme schwarz braun
# rosa - hell blau blau
# braun - wei wei
# braun - schwarz blau schwarz
# schwarz - dunkel grau misch braun
# rot metallic - mokka braun
# schwarz - dunkel grau grau grau
# grun - creme rauch blau rot braun blau
# blau - braun braun
# rosa - grun grun
# schwarz - wei braun braun
# misch - schwarz grun curry apricot schwarz
# grau - dunkel grun wei grun
# wei - gold creme braun
# hell grau meliert - wei wei
# braun - hell gelb gelb
# braun - schwarz wei wei
# rosa - rot rot
# grau - braun braun
# misch - woll wei hell blau grun wei
# braun - woll wei wei
# braun - woll wei wei
# blau - misch misch
# rot - braun wei braun
# definiert - transparent
# braun - wei schwarz wei
# dunkel grun - misch misch
# misch - braun creme braun braun braun
# misch - wei hell grun orange orange
# rot - dunkel orange orange
# rot - rosa rosa
# grau - wei wei
# dunkel grau - schwarz schwarz
# braun - wei hell rosa hell blau wei
# schwarz - grau meliert grau
# rot - rod vit rod
# braun - greige grau
# definiert - transparent
# misch - dunkel blau dunkel rot gelb grau blau blau rot
# braun - wei wei
# schwarz - dunkel grau grau
# braun - blau wei wei
# schwarz - dunkel grau wei grau
# rot - orange orange
# definiert - wei
# misch - nacht blau braun blau
# schwarz - rauch grau grau
# orange - braun wei orchidee schwarz gold gelb braun
# braun - wei dunkel grau wei
# hell gelb - schilf grun
# grun - puder schwarz braun braun braun
# braun - alt rosa rosa gold puder rosa
# braun - schlamm grun
# rot metallic - alt rosa rosa
# misch - braun braun braun
# dunkel rot - rost braun braun
# misch - marine wei braun blau wei
# rot - schwarz dunkel orange hell rosa wei lavendel misch
# taupe - braun braun
# braun - grau grau
# gelb - braun schwarz braun
# braun - wei wei
# silber - rosa gold transparent gold
# bronze - schwarz senf gelb
# rot - wei schwarz rosa rosa
# misch - schwarz grau rosa schwarz rosa
# misch - blau rosa rosa
# hell grau - blau blau blau
# orange - creme braun braun
# senf - gold gelb gelb
# misch - schwarz rot braun rot
# rosa - misch misch
# blau - gras grun grun grun
# taupe - wei alt rosa rosa
# braun - orange orange
# neon gelb - grau rosa grau rosa rot rosa rosa
# gelb - braun braun
# taupe - misch misch
# braun - misch misch
# rot - himbeer schwarz rosa schwarz
# blau - dunkel grun grun schwarz grun
# stein - hell braun braun
# braun - grun grun
# senf - braun taupe wei braun
# misch - blau braun schwarz braun grun wei braun
# wei - schilf hell grun gold grun
# rosa - wei schwarz braun misch
# schwarz - braun braun
# hell grun - stone grau
# braun - wei blau wei
# blau - rosa gelb braun misch
# schwarz - dunkel grau wei grau
# misch - schwarz schwarz
# rosa - hell blau blau
# schwarz - blau dunkel blau grun blau
# misch - blau orange wei wei
# misch - wei schwarz schwarz
# taupe - braun braun
# misch - schwarz wei schwarz
# dunkel grau - braun ne grun
# definiert - braun
# taupe - alt rosa rosa
# stein - grau blau blau
# ocker - braun braun
# blau - grun grun
# schwarz - dunkel grau jade grau
# misch - braun hell blau braun wei blau braun
# braun - woll wei wei
# orange - gelb gelb
# gunmetal - hell gelb grau grau
# schwarz - grau grau
# taupe - braun braun
# blau - grau grau
# hell blau - braun grau schwarz grau
# senf - gelb gelb
# definiert - transparent
# braun - grun grun
# wei - rosa rosa
# grun - dunkel blau blau
# dunkel braun - rosa rosa
# braun - safran gelb
# grun - wei dunkel grau schwarz grau
# rot - cranberry rosa
# wei - dunkel blau braun blau
# braun - schwarz wei schwarz
# braun - misch misch
# wei - grau braun grau braun
# gelb - braun braun
# dunkel grau - schwarz gelb schwarz gelb
# misch - rosa pitaya rosa wei dunkel rosa rosa rosa
# rot - rosa rosa
# schwarz - misch misch
# braun - wei wei
# misch - fuchsia hell grau dunkel grau wei rosa grau
# blau - schwarz ocker wei schwarz
# grau - schwarz blau schwarz
# schwarz - wei wei
# grun - misch misch
# dunkel grun - braun hell rosa braun
# rot metallic - rost braun braun
# grau - braun braun
# schwarz - dunkel grau grau
# ocker - braun braun braun hell blau braun
# braun - creme wei
# grun - braun braun
# dunkel grun meliert - schwarz grau
# braun - wei rosa gelb wei
# braun - greige grau
# braun - creme wei
# schwarz - marine rosa blau
# definiert - wei
# schwarz - wei dunkel grau grau
# grun - hell braun braun
# rot - braun schwarz misch braun
# braun - wei wei
# ocker - braun braun
# rosa - braun braun
# misch - schwarz orange grun wei schwarz
# bronze - braun grau rosa braun
# schwarz - dunkel grau grau
# definiert - hell gelb grun gelb grun
# schwarz - dunkel blau blau
# misch - schwarz gold gold schwarz
# grun - misch misch
# braun - schwarz creme schwarz
# grun - blau nacht blau aqua hell blau blau
# definiert - wei
# rosa - apricot orange
# misch - orange braun wei rauch blau grau blau
# definiert - wei
# taupe - chamois grun rosa kas braun ienbraun braun
# royal - dunkel blau blau
# braun - schwarz wei schwarz
# rosa - rot
# braun - wei wei
# rosa - misch schwarz misch schwarz
# gelb - rosa rosa
# braun - wei wei
# braun - grau misch grau
# braun - wei wei
# misch - braun braun schwarz braun
# braun - hell grau grau
# braun - rosa rosa
# schwarz - misch misch
# grau - tauben blau blau
# dunkel grun - blau blau blau
# blau - grun grun
# definiert -
# braun - woll wei wei
# wei - misch misch
# dunkel blau - schwarz schwarz
# braun - wei wei
# transparent - rosa gold wei gold
# grun - schilf gelb
# braun - wei wei
# grun - braun braun
# schwarz - dunkel blau blau
# rot - orange orange
# schwarz metallic - grun grun
# misch - braun schwarz braun
# hell braun - grau wei dunkel grau grau
# blau - hell grau apricot wei grau
# taupe - braun braun
# rosa - wei wei
# definiert - wei
# misch - hell grun blau limone rot grun blau gelb
# wei - rosa gold gold
# schwarz - wei grau wei grau
# misch - wei orange hell rot wei
# hell grau - grun grun grun
# schwarz - misch misch
# wei - dunkel blau blau
# dunkel blau - braun braun
# braun - schwarz schwarz
# schwarz - rauch grau grau
# braun - creme wei
# definiert - wei
# hell braun - greige grau
# misch - schwarz cappuccino rot braun
# braun - dunkel orange orange
# dunkel grun - schwarz schwarz
# schwarz - schlamm grau
# grun - wei hell blau wei blau
# blau - schwarz braun braun taupe misch
# hell grun - grau grau
# dunkel grau meliert - tauben blau blau
# gold - gelb gelb
# dunkel grau - schwarz schwarz
# definiert - transparent
# rot - grau rosa rosa
# misch - wei orange blau schwarz wei
# stein - wei dunkel braun braun wei
# misch - orange marine blau
# braun - mauve rot
# royal - blau schwarz blau
# grau - grun grun
# misch - blau hell blau azur blau
# grun - grau gelb gelb
# gold - schwarz braun schwarz
# braun - rot rosa
# misch - creme braun
# rot - misch misch
# schwarz - dunkel blau blau
# wei - eierschale braun
# schwarz - dunkel grau grau
# schwarz - dunkel grau grau
# dunkel braun meliert - taupe grun grau
# braun - grau grau
# gelb - wei honig alt rosa rosa misch
# wei - silber transparent silber
# dunkel blau - schwarz schwarz
# wei - braun schwarz braun schwarz
# dunkel grun - umbra braun
# misch - marine grun blau
# braun - woll wei wei
# definiert - wei
# dunkel rot - rost braun braun
# braun - wei wei
# grun - dunkel grau grau
# braun - grau grau
# definiert - wei
# braun - woll wei wei
# misch - wei schwarz wei schwarz
# grun - hell braun blau rot braun
# hell grau - eierschale braun braun
# hell grau - wei meliert wei
# definiert - transparent
# braun - puder rosa
# braun - wei wei
# braun - creme wei
# braun - rost rot rot
# braun ne - grun grun
# stein - tauben blau blau
# misch - marine rot wei blau rot
# braun - wei wei
# schwarz - dunkel grau grau
# wei - braun blau orange braun
# braun - schwarz wei grau
# misch - ocker rosa grun creme gelb
# wei - creme hell braun braun
# braun - dunkel grau grau
# braun - creme wei wei
# grun - dunkel grau grau
# braun - hell rosa rosa rosa
# schwarz - rauch grau grau
# senf - safran gelb
# braun - grau grau
# braun - grun grun grun
# schwarz - safran gelb
# misch - dunkel orange braun braun wei hell blau orange
# rosa - braun gold braun
# braun - hell grau grau
# gold - grun grun
# grau - wei braun rosa silber wei
# misch - wei nacht blau blau
# rosa - hell blau blau
# hell grau - wei blau wei
# definiert - wei
# silber - cappuccino braun
# braun - silber silber
# rosa - rot orange
# schwarz - dunkel grau grau
# ocker - braun braun
# taupe - hell braun braun
# braun - hell gelb gelb
# braun - woll wei wei
# misch - schwarz grun schwarz
# schwarz - orange rot grun hell braun rosa dunkel blau blau
# schwarz - dunkel grau grau
# dark blau blau - grau grau
# braun - wei meliert wei
# orange - rost rot rot
# dunkel blau - grau grau
# dunkel rot - rosa rosa
# misch - schwarz dunkel rot hell braun braun
# blau - grau grau
# silber - hell braun braun
# wei - braun himmel blau gelb braun
# hell blau - braun braun
# dunkel gelb meliert - braun braun
# braun - wei wei
# schwarz - misch misch
# braun - wei wei
# transparent - silber silber
# rosa - braun misch braun
# schwarz - grau meliert graphit grau
# grau - wei wei
# braun - rauch blau blau
# grun - brokat braun
# braun - misch grau gelb gelb
# apricot - grau rot rot
# braun - wei wei
# taupe - rosa rosa
# braun - wei wei
# grau - misch misch
# grun - dunkel blau blau
# misch - wei blau blau
# orange - braun braun
# dunkel grau - schwarz blau schwarz
# braun - orange rosa blau rosa
# grun - hell braun braun
# rosa - hell blau blau
# rot - dunkel rosa rosa
# grau - blau blau
# stein - wei wei
# misch - wei schwarz gelb rosa wei
# braun - creme misch wei
# misch - rosa blau rosa
# grun - schwarz schwarz
# schwarz - grau grau
# hell braun - alt rosa wei rosa
# grun - azur wei blau
# rosa - misch misch
# misch - braun braun braun
# braun - hell grau schwarz rosa alt rosa misch
# rosa - nacht blau wei rot blau
# grau - nacht blau orange blau
# dark blau blau - schwarz schwarz
# grau metallic - schwarz wei taupe schwarz
# definiert - wei
# braun - silber silber
# schwarz meliert - grau grau
# misch - rosa blau blau rosa
# ocker - braun gold braun
# stein - dunkel grau nacht blau wei grau
# misch - dunkel rosa grau meliert himbeer rosa braun rosa grau
# rosa - braun misch braun
# braun - wei schwarz wei
# misch - transparent blau gold gold
# grau - taupe rauch blau hell rosa senf braun blau rosa orange
# braun - wei wei
# hell rot - rosa rosa
# gelb - braun grau senf misch
# schwarz - blau wei blau
# braun - wei wei
# definiert - transparent
# rosa - grau grau
# misch - lavendel hell blau limone orchidee grun rosa
# schwarz - braun braun
# grun - ecru royal blau wei grau
# misch - schwarz wei schwarz
# misch - braun tauben blau grau grun rosa
# braun - grau meliert grau
# hell grau - braun braun
# braun - rosa rosa
# braun - wei wei
# rosa - wei hell rot wei
# braun - alt rosa rosa
# hell grau - schwarz braun rot schwarz
# orange - misch schwarz misch
# rot - misch misch
# rosa - puder braun
# grun - hell grau grau
# braun - woll wei wei
# hell braun - taupe grau
# definiert - transparent
# schwarz - blau blau
# taupe - braun braun
# schwarz - dunkel grau grau
# wei - silber silber
# grun - braun braun
# hell blau - grun wei grun
# braun - greige grau
# schwarz - dunkel grau grau
# stein - braun schwarz braun schwarz
# orange - rosa rosa
# blau - grau grau
# braun - wei wei
# rot - rosa rosa
# braun - wei schwarz hummer hell blau wei
# schwarz - dunkel grau grau
# braun - ecru rot rosa gelb gras grun wei
# misch - grau rosa grau blau blau rosa
# blau - grun grun
# grau - schwarz blau wei misch
# braun - wei rot wei
# braun - woll wei schwarz wei
# rosa - braun braun
# hell blau - misch misch
# misch - braun wei wei
# braun - wei kitt nacht blau grau rot misch
# braun - wei n rot rot
# wei - creme braun rosa braun
# rot - aubergine braun
# rosa - orange rot orange
# rosa - rauch blau blau meliert blau
# wei - transparent rosa transparent
# braun - taupe grau
# rosa - braun braun
# taupe - grau grau
# wei - creme dunkel gelb grun braun
# grau - schwarz schwarz
# definiert - wei grau
# misch - braun hell braun schwarz braun
# transparent - schwarz silber wei schwarz
# dunkel blau - schwarz wei schwarz
# braun - wei wei
# gold - gelb gelb
# braun - grau rosa rosa
# rosa - schwarz melone limette misch
# grun - dunkel grau grau
# misch - blau rot grun grun
# royal - blau blau blau
# schwarz - grun grun
# wei - braun braun
# misch - dunkel blau blau
# wei - hell blau hell grun hell braun blau
# misch - schwarz kiwi rosa rot dunkel braun schwarz
# orange - mauve gelb wei rosa gelb
# definiert - transparent
# dunkel blau - schwarz wei grau
# grau - creme braun
# blau - grun gold grun
# orange - safran gelb
# grun - gelb gelb
# braun - ecru dunkel grun wei grun
# rosa - puder braun
# rot metallic - dunkel braun braun
# senf - dunkel blau gelb wei gelb
# schwarz - grun grun
# misch - braun schwarz creme dunkel orange braun
# misch - schwarz alt rosa grun rot grun schwarz
# gelb - braun schwarz wei braun
# dunkel blau - braun creme grau schwarz grau
# rot metallic - tauben blau blau
# blau - grau wei grau
# braun - woll wei silber wei
# dunkel grun - gold schwarz braun
# dunkel gelb meliert - braun braun
# braun - wei wei
# taupe - grau grau
# braun - hell grau rosa schwarz grau
# misch - wei braun rot alt rosa wei
# wei - schwarz rosa gold schwarz
# braun - creme wei
# braun - hell gelb wei gelb
# braun - wei wei
# schwarz - dunkel grau grau
# schwarz - blau rosa dunkel grun hell rosa blau
# apricot - braun braun
# gunmetal - silber grau grau
# wei - blau blau
# taupe - braun braun
# grun - schlamm grau
# grun - basalt grau grau
# ocker - braun braun
# rot - rosa rosa
# braun - dunkel orange orange
# misch - nacht blau orange wei blau
# hell grau - braun braun
# definiert - grau gelb
# grun - braun meliert braun
# misch - nacht blau orange rot hell grun wei braun blau rot
# ocker - hell braun brokat braun
# grun - hell blau wei blau
# rot - dunkel braun braun
# grun - dunkel grau braun grau
# braun - dunkel grun grun
# braun - woll wei misch wei
# ocker - curry gelb
# hell gelb - creme braun
# rot metallic - braun braun
# rot - purpur misch rosa
# braun - creme wei
# blau metallic - hell braun braun
# schwarz - blau blau
# grun - rosa gold grau grau
# braun - grau grau
# rosa - creme braun
# rosa - dunkel orange braun rot misch
# schwarz - grau wei grau
# blau - grau grau
# misch - hell blau dunkel blau karmin rot blau
# wei - silber transparent silber
# wei - silber transparent silber
# grun - dunkel braun braun
# braun - wei wei
# braun - creme wei
# grau - himmel blau wei gold schwarz blau
# braun - puder rosa
# rosa - misch rot rot misch
# wei - braun braun
# schwarz - misch misch
# braun - wei blau blau
# schwarz - marine rot blau
# wei - transparent silber silber
# schwarz metallic - dunkel grun grau meliert grun
# blau - jade wei grun
# rosa - hell grau grau
# apricot - braun braun
# gunmetal - misch misch
# braun - grau grau
# taupe - rosa rosa
# gunmetal - gold schwarz gold
# misch - braun schwarz braun
# schwarz - dunkel grau grau
# grun - brokat braun
# grun meliert - braun braun
# misch - silber hell rosa silber
# rot - himbeer rosa
# bronze - hell braun braun
# stein - wei gold wei
# misch - puder schwarz wei rosa
# blau - hell rosa rosa
# braun - wei schwarz misch wei
# rot - pfirsich rosa
# grau - schwarz schwarz
# dunkel blau - grun schwarz schwarz
# braun - wei misch wei
# braun - misch schwarz
# rosa - misch misch
# orange - misch misch
# braun - wei wei
# misch - wei rot braun wei rot
# schwarz - dunkel grau grau
# grun - eierschale schwarz tauben blau chamois braun
# misch - rot schwarz jade wei rot schwarz
# misch - hell braun schwarz wei braun
# rot - pfirsich rosa
# apricot - rosa wei
# hell braun - rosa rosa
# rot - pfirsich braun orange
# blau - misch schwarz misch
# rosa - misch misch
# senf - rauch blau gelb gelb
# rosa - cappuccino braun
# senf - braun braun
# braun - rosa rosa
# rot - aubergine rosa
# braun - silber silber
# braun - rosa wei rot
# braun - silber grau grau
# braun - creme wei
# grun - braun braun
# schwarz - wei dunkel blau blau
# braun - grau schwarz grau
# misch - schwarz wei schwarz
# braun - rosa rosa
# grun meliert - braun wei
# braun - woll wei wei
# schwarz - dunkel grau gelb grau
# grau - dunkel braun schwarz braun
# taupe - braun hell braun braun
# braun - hell grau grau
# schwarz - misch misch
# wei - creme braun
# misch - creme apricot schwarz braun braun orange
# wei - creme braun
# grun - hell grau grau
# hell braun - alt rosa rosa
# braun - wei royal blau wei
# grun - taupe grau
# schwarz - graphit grau
# grun - dunkel braun braun
# senf - braun kas braun ienbraun hell braun wei schwarz braun
# rosa - hell blau blau
# definiert - transparent
# schwarz - braun ne grun
# gunmetal - silber grau grau
# misch - rot blau wei rot
# braun - wei wei
# schwarz - rot rot
# blau - creme wei
# silber - hell braun braun
# royal - hell blau blau
# braun - wei meliert rot wei
# royal - blau blau blau
# rosa - misch schwarz schwarz
# dunkel blau - alt rosa rosa
# rot metallic - pfirsich orange
# ocker - braun braun
# definiert -
# rosa - blau meliert blau
# braun - hell grau grau
# braun - alt rosa rosa
# braun - wei dunkel grau wei
# rosa - grenadine rot
# orange - alt rosa rosa
# misch - braun grau grun braun braun
# braun - wei wei
# grun - rosa blau grau rosa wei misch
# braun - orange orange
# braun - hell gelb gelb
# grun - misch misch
# schwarz - grau grau
# schwarz - grau meliert grau
# braun - creme wei
# ocker - braun dunkel braun braun
# braun - alt rosa rosa
# rot - braun braun
# braun - grun grun
# stein - basalt grau grau
# braun - rosa rosa
# dunkel blau - misch misch
# misch - creme orange rosa grau grun braun
# grau - schwarz schwarz
# rosa - burgunder rot
# gunmetal - silber silber
# taupe - braun hell grau grau
# schwarz - braun dunkel braun braun
# blau - grau grau
# stein - stone braun wei braun
# wei - hell grau dunkel grun grau
# braun - rosa
# blau - grun grun
# definiert - transparent
# rosa - rot orange rot orange
# grau - silber schwarz silber
# braun - wei blau wei
# wei - rosa gold gold
# rosa - taupe grau
# stein - misch braun braun
# braun - taupe grau
# grun - blau blau
# hell grun - grau grau
# grun - aqua blau
# wei - silber gold silber gold
# blau - schwarz orange wei rauch grau grau
# braun - ecru wei
# wei - hell blau blau
# schwarz - misch misch
# rosa - hell braun braun
# schwarz - dunkel grun grun
# hell braun - safran gelb
# schwarz - braun hell braun braun
# dunkel gelb meliert - braun braun
# misch - creme braun
# blau - rosa rosa
# taupe - kitt braun
# schwarz - braun wei braun
# misch - dunkel rosa nacht blau hell blau rot orange blau
# schwarz - wei wei misch
# rot - dunkel rosa rosa
# dunkel blau - grau meliert grau
# hell grun - creme braun
# grun - hell braun braun
# blau - jade grun
# misch - wei grun rosa dunkel rosa rosa
# braun - woll wei wei
# braun - wei wei
# wei - hell gelb braun gelb
# braun - wei grau misch wei
# grun - hell braun braun
# dunkel blau - schwarz rosa gelb grun misch
# wei - creme braun
# braun - woll wei wei
# blau - braun grun wei
# definiert - gold
# rosa - grau rot kobalt blau wei n rot rot
# mauve - braun braun
# braun - wei wei
# hell blau - braun grun wei
# schwarz - silber silber
# gold - schwarz schwarz
# transparent - silber schwarz silber
# hell grun - transparent
# misch - rot hell rosa mandarine wei grun rosa
# schwarz - dunkel blau misch blau
# rosa - schwarz wei rot rot wei
# braun - rot rot
# misch - braun grun braun grun
# blau - grun grun
# braun - orange rosa blau rosa
# rot - rosa rosa
# wei - schwarz schwarz
# taupe - braun braun
# bronze - gold gold
# misch - rosa grau grun rosa grun
# braun - grun grun
# rosa - braun braun
# wei - braun braun
# braun - wei schwarz wei
# grun - misch misch
# grun - schwarz schwarz
# braun - grau blau blau
# braun - rosa alt rosa rosa
# misch - rost rot hell braun rot
# grun - dunkel braun braun
# dunkel grau - schwarz wei blau schwarz
# dunkel blau - schwarz schwarz
# misch - gold gold
# definiert - wei
# hell blau - dunkel orange orange
# braun - wei wei
# rosa - cappuccino braun
# rot - schwarz schwarz
# rosa - hell blau blau
# grun - blau blau
# misch - nacht blau blau
# stein - wei gold wei
# grun - braun braun
# braun - wei wei
# gelb - rosa misch rosa
# braun - schwarz rot rot
# definiert - wei
# misch - rosa rosa schwarz gold rosa
# dunkel grun - schwarz grau
# braun - puder rosa
# braun - wei wei
# dunkel grau meliert - blau puder grun blau
# misch - rosa hell blau rosa blau
# ocker - braun braun rot rosa braun
# braun - hell grau grau
# braun - dunkel grun creme grun
# gelb - braun misch braun
# braun - wei wei
# dunkel blau - schwarz misch schwarz
# silber - grau wei grau
# grun - misch misch
# rosa - wei hell blau blau wei
# braun - wei wei
# braun - wei wei
# schwarz - misch misch
# hell blau - grau grun grun
# hell grau - blau meliert blau
# misch - creme dunkel blau blau
# wei - grau gelb gelb
# stein - braun braun
# grau - wei hell braun wei braun
# grun - mokka braun
# braun - grau rot rot
# orange - gold gelb gelb
# braun - wei wei
# braun - schwarz hell grau grau
# braun - wei wei
# braun - grau hell grau wei grau
# braun - orange orange
# hell grau - wei meliert wei
# definiert - wei
# grun - hell grau grau
# blau - gelb gelb
# stein - braun gold wei
# braun - wei alt rosa wei
# wei - silber transparent transparent
# schwarz - dunkel braun hell braun braun
# grau - silber silber
# taupe - hell braun braun
# rosa - wei jade grun
# braun - gold gold
# braun - woll wei wei
# grun - blau blau
# grau - hell grun grun
# misch - wei dunkel rosa schwarz royal blau grau rosa wei
# dunkel rot - rost braun braun
# taupe - dunkel braun braun
# braun - puder rosa
# misch - dunkel braun wei dunkel rot dunkel rosa pfirsich braun
# braun - ecru wei
# rot - hummer rosa
# dunkel blau meliert - basalt grau grau
# gelb - wei rot rot
# braun - grau gelb gelb
# definiert - transparent
# stein - hell grau grau
# grun - braun braun
# braun - schwarz wei schwarz
# grun - braun braun
# braun - grau blau grau
# wei - silber silber
# braun - wei wei
# braun - stone grau
# braun - wei wei
# silber - hell braun braun
# braun - wei wei
# braun - misch misch
# braun - hell grau wei wei
# dunkel gelb - braun braun schwarz braun
# definiert - transparent
# braun - gold gelb gold gelb
# definiert - transparent
# schwarz blau - grau grau
# schwarz - nacht blau wei melone dunkel rot alt rosa blau
# grun - braun meliert braun
# gelb - orange orange
# wei blau - braun braun
# grau - grun grun
# wei - schwarz transparent schwarz
# wei - silber silber
# braun - wei misch wei
# wei - silber silber
# misch - schwarz schwarz
# braun - grun grun
# grun - misch misch
# taupe - silber grau silber
# braun - rosa
# misch - wei grau blau kitt wei blau
# definiert - transparent gold
# misch - hell blau nacht blau wei grau gelb blau
# wei - misch misch
# gold - braun braun
# dunkel blau - wei schwarz schwarz
# rot - wei hell braun dunkel braun pitaya rosa
# misch - dunkel braun chamois wei pfirsich braun
# rosa - braun rot pitaya rot
# misch - apricot schwarz braun braun orange
# grun - braun braun
# schwarz - grun grun
# grun - braun meliert braun
# misch - blau orange blau orange
# ocker - grun grun
# wei - silber silber
# orange - braun wei braun
# braun - wei misch wei
# senf - gold gelb gelb
# blau - dunkel grau schwarz hell grau grau orange grau
# misch - braun braun
# misch - cappuccino braun pueblo braun
# braun - wei rauch grau wei
# hell grau - dunkel grun grun
# braun - wei hell rot rosa grun gelb misch
# rosa - rost rot schwarz rot
# grau - wei wei
# schwarz - dunkel braun braun
# rosa - pfirsich orange
# braun - wei wei
# blau - misch misch
# dunkel blau - misch misch
# senf - braun braun
# grun - stone grau
# dunkel rot - rosa rosa
# misch - schwarz wei dunkel braun pfirsich schwarz
# blau - misch misch
# hell blau - grau braun schwarz grau
# schwarz - blau wei blau
# schwarz - blau rosa wei blau
# braun - wei wei
# braun - wei wei
# grun - wei grau blau dunkel grau grau
# hell grau - braun braun
# hell blau - misch misch
# braun - schwarz schwarz
# braun - wei wei
# braun - wei wei
# dunkel blau - misch misch
# gelb - orange wei orange
# grun - dunkel grau grau
# misch - schwarz wei schwarz
# hell grau - wei meliert schwarz rot safran wei
# misch - blau wei braun blau
# dunkel rot - rosa rosa
# misch - braun pfirsich grun grau blau himbeer braun
# gunmetal - silber grau grau
# rot - rosa rosa
# orange - rost braun braun
# dunkel gelb meliert - creme braun
# grun - dunkel grau schwarz grau
# taupe - hell braun braun
# dunkel rot - rosa rosa
# schwarz - misch misch
# braun - grau meliert grau
# taupe - pitaya rosa
# gold - schwarz schwarz
# braun - schwarz wei hell blau schwarz
# rosa gold - rost braun braun wei wei braun
# ocker - braun braun
# rosa - kirsch rot schwarz rot
# dunkel grau - braun braun
# rot - braun braun
# braun - grun grun
# braun - wei wei
# grun - schwarz hell braun braun braun schwarz
# senf - hell braun creme dunkel braun braun
# braun - wei wei
# apricot - braun braun
# rosa - misch misch
# dunkel grau - grun grun

# %%
len(color_not_matched)
# Out:
# 1568
